# %% [markdown]
# ### A. Watch this first pre-lecture video ("Hypothesis testing. Null vs alternative") addressing the question "What is a hypothesis?"<br>

# %% [markdown]
# idea can be tested by using data.

# %% [markdown]
# ### B. Watch this second pre-lecture video ("What is a p-value") providing an intuitivie introduction to p-values <br>

# %% [markdown]
# p-value helps us to decide whether keep believing old idea or new idea by observing the value. if p-value is smaller or equal than 0.05, then we have enough evidence to believe the new idea.

# %% [markdown]
# ### 1. The "first pre-lecture video" (above) describes hypothesis testing as addressing "an idea that can be tested", and the end of the video then discusses what our actual intended purpose in setting up a null hypothesis is. What is the key factor that makes the difference between ideas that can, and cannot be examined and tested statistically?  What would you describe is the key "criteria" defining what a good null hypothesis is? And what is the difference between a null hypothesis and an alternative hypothesis in the context of hypothesis testing? Answer these questions with concise explanations in your own words.<br>

# %% [markdown]
# the key factor is the verifiability of hypotheses. we need to come up with ideas can be tested by using data. we also need enough data informations and clear research objectives.
#
# a good null hypothesis should be clear, and is verifiable by data.
#
# The null hypothesis is the default hypothesis used as a benchmark for testing in research. the alternative hypothesis has a difference relative to the null hypothesis and is the hypothesis we wish to prove.

# %% [markdown]
# ### 2. Towards the end of the "first pre-lecture" video (above) it is stated that, "It is important to note that outcomes of tests refer to the population parameter, rather than the sample statistic! As such, the result that we get is for the population." In terms of the distinctions between the concepts of $x_i\!$'s, $\bar x$, $\mu$, and $\mu_0$, how would you describe what the sentence above means? Explain this concisely in your own words for a "non-statsitical" audience, defining the technical statistical terminology you use in your answer.<br>

# %% [markdown]
# 𝑥𝑖 's:the actual value of sample data
#
# 𝑥¯:the sample mean value of the actual values of the sample data
#
# 𝜇:the overall mean value. different from 𝑥¯, this value is usually a variable.
#
# 𝜇0:overall Values set in hypothesis testingused to compare with sample mean value(𝑥¯)
#
# sample data: a portion of data randomly selected from a larger population

# %% [markdown]
# ### 4. The second "Pre-lecture" video (above) describes suggest that a smaller p-value makes the null hypothesis look more ridiculous. Explain why this is in your own words in a way that makes the most sense to you, clarifying the meaning of any technical statistical terminology you use in your answer.<br>

# %% [markdown]
# A smaller p-value means that there is only a very small probability that such data will be observed if the null hypothesis holds. This means that the difference between the data and the null hypothesis is so large that the null hypothesis is likely to be wrong.

# %% [markdown]
# ### 8. Complete the following assignment.

# %% [markdown]
# Problem Introduction

# %% [markdown]
# in this assignment, we are investigating whether there is a statistically significant difference in the ability of sta130 students to recognize the order of milk and tea in a cup. We conducted a similar experiment on a sample of sta130 students to the “classic experiment Bristol's method of being able to distinguish between pouring milk and tea”. Our focus was to determine whether the observed success rate of students correctly recognizing the order was higher than would be expected by chance.

# %% [markdown]
# Relationship between this experiment and the original with Fisher and Bristol

# %% [markdown]
# in contrast to the original Fischer and Bristol experiments, sta130 experiment looked at a much broader group of students and assessed their collective ability to discriminate sequences in the absence of any individualized preferences.

# %% [markdown]
# Statements of the Null Hypothesis and Alternative hypothesis

# %% [markdown]
# the null hypothesis states that the proportion of students who correctly identify the order of milk and tea is equal to the expected proportion of random guesses: H0:p == 0.5

# %% [markdown]
# the alternative hypothesis states that the proportion of students correctly identifying the order of milk and tea is not equal to the expected: HA:p != 0.5

# %% [markdown]
# Quantitative Analysis

# %% [markdown]
# Methodology Code and Explanations

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Given data
n = 80  # sample size
x = 49  # number of correct identifications
p_hat = x / n  # sample proportion

# Null hypothesis proportion
p_0 = 0.5

# Standard error calculation
SE = np.sqrt(p_0 * (1 - p_0) / n)

# Z-statistic calculation
Z = (p_hat - p_0) / SE

# P-value calculation for one-tailed test
p_value = 1 - stats.norm.cdf(Z)

# Results
print(f"Sample Proportion (p̂): {p_hat:.4f}")
print(f"Z-Statistic: {Z:.4f}")
print(f"P-Value: {p_value:.4f}")

# Supporting visualization
x_values = np.linspace(-3, 3, 100)
y_values = stats.norm.pdf(x_values, 0, 1)

plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label='Standard Normal Distribution', color='blue')
plt.fill_between(x_values, y_values, where=(x_values >= Z), color='red', alpha=0.5, label='P-Value Area')
plt.axvline(Z, color='orange', linestyle='dashed', linewidth=2, label='Z-Statistic')
plt.title('Standard Normal Distribution and P-Value')
plt.xlabel('Z-Score')
plt.ylabel('Probability Density')
plt.legend()
plt.grid()
plt.show()
# Out:
# Sample Proportion (p̂): 0.6125
# Z-Statistic: 2.0125
# P-Value: 0.0221

# %% [markdown]
# Findings and Discussion

# %% [markdown]
# after running the analysis, if the p-value is less than 0.05, we reject the null hypothesis in favor of the alternative hypothesis, which suggests that the sta130 students are able to distinguish the order of milk and tea better than the probability predictions.

# %% [markdown]
# Conclusion regarding the Null Hypothesis

# %% [markdown]
# If the p-value is less than 0.05, we will conclude that we have evidence against the null hypothesis indicating that the students are indeed able to distinguish between the two methods of pouring.
#
# Conversely, if the p-value is greater than 0.05, we are unable to reject the null hypothesis, which suggests that the students' ability to identify the order is consistent with random guessing.

# %% [markdown]
# chatgpt summary:
# In this session, we covered a statistical analysis based on a famous anecdote involving Ronald Fisher and Dr. Muriel Bristol regarding the order of pouring milk and tea. Here’s a summary of what we discussed:
#
# 1. **Methodology Code and Explanation**:
#    - We developed a hypothesis test to evaluate whether students in a STA130 class could correctly identify the order of pouring milk and tea.
#    - We described the population (all STA130 students) and sample (80 students).
#    - We defined the null hypothesis \( H_0: p = 0.5 \) (students are guessing) and the alternative hypothesis \( H_A: p > 0.5 \) (students can distinguish the order).
#    - We calculated the sample proportion, standard error, Z-statistic, and P-value to assess the null hypothesis.
#
# 2. **Python Code Implementation**:
#    - I provided a Python code snippet that performs the hypothesis test, calculates the required statistics, and generates a visualization of the standard normal distribution and the P-value area.
#
# 3. **Code Explanation**:
#    - We went through the code step-by-step, explaining how each section contributes to the overall analysis, including the significance of calculating the Z-statistic and P-value, as well as the visualization of results.
#
# Overall, the session focused on performing a statistical hypothesis test for a practical scenario, with an emphasis on clarity and thoroughness in both the methodology and code implementation. If you have any further questions or need additional assistance, feel free to ask!

# %% [markdown]
# chatgpt link:https://chatgpt.com/share/670f5126-226c-8002-aaa0-f4047d51c0b8

# %% [markdown]
# chatgpt link:https://chatgpt.com/share/670f5195-3650-8002-8228-0dd189e00b10
